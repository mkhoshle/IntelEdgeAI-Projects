# %%
import torch
import torch.onnx
import torch.nn as nn

# %%
class LSCCNN(nn.Module):
    # nofreeze - 'True' if no layers are to be frozen during training
    # trainable - if False, whole network has requires_grad=False set
    def __init__(self, args=None, cfg=None, name='scale_4', init_weights=True, batch_norm=False, nofreeze=True,
                 output_downscale=None, trainable=True):
        super(LSCCNN, self).__init__()
        self.name = name
#         self.args = args
        # OPT: Use torchvision.transforms instead
        if torch.cuda.is_available():
            self.rgb_means = torch.cuda.FloatTensor([104.008, 116.669, 122.675])
        else:
            self.rgb_means = torch.FloatTensor([104.008, 116.669, 122.675])
        self.rgb_means = torch.autograd.Variable(self.rgb_means, requires_grad=False).unsqueeze(0).unsqueeze(
            2).unsqueeze(3)
        layers = []
        in_channels = 3
        self.relu = nn.ReLU(inplace=True)
        self.conv1_1 = nn.Conv2d(in_channels, 64, kernel_size=3, padding=1)
        self.conv1_2 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv2_1 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv2_2 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv3_1 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv3_2 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.conv3_3 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
    
        self.conv4_1 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.conv4_2 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv4_3 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv5_1 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv5_2 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv5_3 = nn.Conv2d(512, 512, kernel_size=3, padding=1)

        self.convA_1 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.convA_2 = nn.Conv2d(256, 128, kernel_size=3, padding=1)
        self.convA_3 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        self.convA_4 = nn.Conv2d(64, 32, kernel_size=3, padding=1)
        self.convA_5 = nn.Conv2d(32, 4, kernel_size=3, padding=1)
        
        self.convB_1 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.convB_2 = nn.Conv2d(256, 128, kernel_size=3, padding=1)
        self.convB_3 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        self.convB_4 = nn.Conv2d(64, 32, kernel_size=3, padding=1)
        self.convB_5 = nn.Conv2d(32, 4, kernel_size=3, padding=1)

        self.convC_1 = nn.Conv2d(384, 256, kernel_size=3, padding=1)
        self.convC_2 = nn.Conv2d(256, 128, kernel_size=3, padding=1)
        self.convC_3 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        self.convC_4 = nn.Conv2d(64, 32, kernel_size=3, padding=1)
        self.convC_5 = nn.Conv2d(32, 4, kernel_size=3, padding=1)

        self.convD_1 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.convD_2 = nn.Conv2d(256, 128, kernel_size=3, padding=1)
        self.convD_3 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        self.convD_4 = nn.Conv2d(64, 32, kernel_size=3, padding=1)
        self.convD_5 = nn.Conv2d(32, 4, kernel_size=3, padding=1)

        self.conv_before_transpose_1 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.transpose_1 = nn.ConvTranspose2d(256, 256, kernel_size=3, stride=2, padding=1, output_padding=1)
        self.conv_after_transpose_1_1 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        
        self.transpose_2 = nn.ConvTranspose2d(256, 256, kernel_size=3, stride=2, padding=1, output_padding=1)
        self.conv_after_transpose_2_1 = nn.Conv2d(256, 128, kernel_size=3, padding=1)

        self.transpose_3 = nn.ConvTranspose2d(256, 256, kernel_size=3, stride=4, padding=0, output_padding=1)
        self.conv_after_transpose_3_1 = nn.Conv2d(256, 128, kernel_size=3, padding=1)


        self.transpose_4_1_a = nn.ConvTranspose2d(256, 256, kernel_size=3, stride=4, padding=0, output_padding=1)
        self.transpose_4_1_b = nn.ConvTranspose2d(256, 256, kernel_size=3, stride=2, padding=1, output_padding=1)
        self.conv_after_transpose_4_1 = nn.Conv2d(256, 64, kernel_size=3, padding=1)
        
        self.transpose_4_2 = nn.ConvTranspose2d(256, 256, kernel_size=3, stride=4, padding=0, output_padding=1)
        self.conv_after_transpose_4_2 = nn.Conv2d(256, 64, kernel_size=3, padding=1)

        self.transpose_4_3 = nn.ConvTranspose2d(128, 128, kernel_size=3, stride=2, padding=1, output_padding=1)
        self.conv_after_transpose_4_3 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        
        self.conv_middle_1 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.conv_middle_2 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv_middle_3 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv_mid_4 = nn.Conv2d(512, 256, kernel_size=3, padding=1)

        self.conv_lowest_1 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv_lowest_2 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.conv_lowest_3 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.conv_lowest_4 = nn.Conv2d(256, 128, kernel_size=3, padding=1)

        self.conv_scale1_1 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv_scale1_2 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv_scale1_3 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        
    # initialize all conv W' with a He normal initialization
    def _initialize_weights(self):
        if True:
            for m in self.modules():
                if isinstance(m, nn.Conv2d):
                    m.weight.data.normal_(std=0.01, mean=0.0)
                    m.bias.data.zero_()
    def mean_over_multiple_dimensions(self, tensor, axes):
        for ax in sorted(axes, reverse=True):
            tensor = torch.mean(tensor, dim=ax, keepdim=True)
        return tensor

    def max_over_multiple_dimensions(self, tensor, axes):
        for ax in sorted(axes, reverse=True):
            tensor, _ = torch.max(tensor, ax, keepdim=True)
        return tensor

    def forward(self, x):
        mean_sub_input = x
        mean_sub_input -= self.rgb_means

        #################### Stage 1 ##########################
        
        main_out_block1 = self.relu(self.conv1_2(self.relu(self.conv1_1(mean_sub_input))))
        main_out_pool1 = self.pool1(main_out_block1)

        main_out_block2 = self.relu(self.conv2_2(self.relu(self.conv2_1(main_out_pool1))))
        main_out_pool2 = self.pool2(main_out_block2)

        main_out_block3 = self.relu(self.conv3_3(self.relu(self.conv3_2(self.relu(self.conv3_1(main_out_pool2))))))
        main_out_pool3 = self.pool3(main_out_block3)

        main_out_block4 = self.relu(self.conv4_3(self.relu(self.conv4_2(self.relu(self.conv4_1(main_out_pool3))))))
        main_out_pool4 = self.pool3(main_out_block4)

        main_out_block5 = self.relu(self.conv_before_transpose_1(self.relu(self.conv5_3(self.relu(self.conv5_2(self.relu(self.conv5_1(main_out_pool4))))))))

        main_out_rest = self.convA_5(self.relu(self.convA_4(self.relu(self.convA_3(self.relu(self.convA_2(self.relu(self.convA_1(main_out_block5)))))))))
        if self.name == "scale_1":
            return main_out_rest
        ################## Stage 2 ############################

        sub1_out_conv1 = self.relu(self.conv_mid_4(self.relu(self.conv_middle_3(self.relu(self.conv_middle_2(self.relu(self.conv_middle_1(main_out_pool3))))))))
        sub1_transpose = self.relu(self.transpose_1(main_out_block5))
        sub1_after_transpose_1 = self.relu(self.conv_after_transpose_1_1(sub1_transpose))

        sub1_concat = torch.cat((sub1_out_conv1, sub1_after_transpose_1), dim=1)

        sub1_out_rest = self.convB_5(self.relu(self.convB_4(self.relu(self.convB_3(self.relu(self.convB_2(self.relu(self.convB_1(sub1_concat)))))))))
        if self.name == "scale_2":
            return main_out_rest, sub1_out_rest
        ################# Stage 3 ############################
        
        sub2_out_conv1 = self.relu(self.conv_lowest_4(self.relu(self.conv_lowest_3(self.relu(self.conv_lowest_2(self.relu(self.conv_lowest_1(main_out_pool2))))))))
        sub2_transpose = self.relu(self.transpose_2(sub1_out_conv1))
        sub2_after_transpose_1 = self.relu(self.conv_after_transpose_2_1(sub2_transpose))
        
        sub3_transpose = self.relu(self.transpose_3(main_out_block5))
        sub3_after_transpose_1 = self.relu(self.conv_after_transpose_3_1(sub3_transpose))
        
        sub2_concat = torch.cat((sub2_out_conv1, sub2_after_transpose_1, sub3_after_transpose_1), dim=1)

        sub2_out_rest = self.convC_5(self.relu(self.convC_4(self.relu(self.convC_3(self.relu(self.convC_2(self.relu(self.convC_1(sub2_concat)))))))))

        if self.name == "scale_3":
            return main_out_rest, sub1_out_rest, sub2_out_rest

        ################# Stage 4 ############################
        sub4_out_conv1 = self.relu(self.conv_scale1_3(self.relu(self.conv_scale1_2(self.relu(self.conv_scale1_1(main_out_pool1))))))

        # TDF 1
        tdf_4_1_a = self.relu(self.transpose_4_1_a(main_out_block5))
        tdf_4_1_b = self.relu(self.transpose_4_1_b(tdf_4_1_a))
        after_tdf_4_1 = self.relu(self.conv_after_transpose_4_1(tdf_4_1_b))
        
        # TDF 2
        tdf_4_2 = self.relu(self.transpose_4_2(sub1_out_conv1))
        after_tdf_4_2 = self.relu(self.conv_after_transpose_4_2(tdf_4_2))

        # TDF 3
        tdf_4_3 = self.relu(self.transpose_4_3(sub2_out_conv1))
        after_tdf_4_3 = self.relu(self.conv_after_transpose_4_3(tdf_4_3))

        sub4_concat = torch.cat((sub4_out_conv1, after_tdf_4_1, after_tdf_4_2, after_tdf_4_3), dim=1)
        sub4_out_rest = self.convD_5(self.relu(self.convD_4(self.relu(self.convD_3(self.relu(self.convD_2(self.relu(self.convD_1(sub4_concat)))))))))

        if self.name == "scale_4":
            return main_out_rest, sub1_out_rest, sub2_out_rest, sub4_out_rest

# %%
weights_path = "qnrf/models/train2/snapshots/scale_4_epoch_46.pth"

# %%
# A model class instance (class not shown)
model = LSCCNN()

# Load the weights from a file (.pth usually)
state_dict = torch.load(weights_path, map_location='cpu')

# %%
state_dict.keys()
# Out:
# dict_keys(['optimizer', 'state_dict', 'epoch'])

# %%
# Load the weights now into a model net architecture defined by our class
model.load_state_dict(state_dict['state_dict'])
# Out:
# <All keys matched successfully>

# %%
# Create the right input shape (e.g. for an image)
sample_batch_size = 4
input_shape = (3, 224, 224)  # channel, height, width

dummy_input = torch.randn(sample_batch_size, *input_shape)

# %%
torch.__version__
# Out:
# '1.5.0'

# %%
torch.onnx.export(model, dummy_input, "onnx_model_name.onnx",
                    export_params=True,verbose=True)
# Out:
# graph(%0 : Float(4, 3, 224, 224),
#       %conv1_1.weight : Float(64, 3, 3, 3),
#       %conv1_1.bias : Float(64),
#       %conv1_2.weight : Float(64, 64, 3, 3),
#       %conv1_2.bias : Float(64),
#       %conv2_1.weight : Float(128, 64, 3, 3),
#       %conv2_1.bias : Float(128),
#       %conv2_2.weight : Float(128, 128, 3, 3),
#       %conv2_2.bias : Float(128),
#       %conv3_1.weight : Float(256, 128, 3, 3),
#       %conv3_1.bias : Float(256),
#       %conv3_2.weight : Float(256, 256, 3, 3),
#       %conv3_2.bias : Float(256),
#       %conv3_3.weight : Float(256, 256, 3, 3),
#       %conv3_3.bias : Float(256),
#       %conv4_1.weight : Float(512, 256, 3, 3),
#       %conv4_1.bias : Float(512),
#       %conv4_2.weight : Float(512, 512, 3, 3),
#       %conv4_2.bias : Float(512),
#       %conv4_3.weight : Float(512, 512, 3, 3),
#       %conv4_3.bias : Float(512),
#       %conv5_1.weight : Float(512, 512, 3, 3),
#       %conv5_1.bias : Float(512),
#       %conv5_2.weight : Float(512, 512, 3, 3),
#       %conv5_2.bias : Float(512),
#       %conv5_3.weight : Float(512, 512, 3, 3),
#       %conv5_3.bias : Float(512),
#       %convA_1.weight : Float(256, 256, 3, 3),
#       %convA_1.bias : Float(256),
#       %convA_2.weight : Float(128, 256, 3, 3),
#       %convA_2.bias : Float(128),
#       %convA_3.weight : Float(64, 128, 3, 3),
#       %convA_3.bias : Float(64),
#       %convA_4.weight : Float(32, 64, 3, 3),
#       %convA_4.bias : Float(32),
#       %convA_5.weight : Float(4, 32, 3, 3),
#       %convA_5.bias : Float(4),
#       %convB_1.weight : Float(256, 512, 3, 3),
#       %convB_1.bias : Float(256),
#       %convB_2.weight : Float(128, 256, 3, 3),
#       %convB_2.bias : Float(128),
#       %convB_3.weight : Float(64, 128, 3, 3),
#       %convB_3.bias : Float(64),
#       %convB_4.weight : Float(32, 64, 3, 3),
#       %convB_4.bias : Float(32),
#       %convB_5.weight : Float(4, 32, 3, 3),
#       %convB_5.bias : Float(4),
#       %convC_1.weight : Float(256, 384, 3, 3),
#       %convC_1.bias : Float(256),
#       %convC_2.weight : Float(128, 256, 3, 3),
#       %convC_2.bias : Float(128),
#       %convC_3.weight : Float(64, 128, 3, 3),
#       %convC_3.bias : Float(64),
#       %convC_4.weight : Float(32, 64, 3, 3),
#       %convC_4.bias : Float(32),
#       %convC_5.weight : Float(4, 32, 3, 3),
#       %convC_5.bias : Float(4),
#       %convD_1.weight : Float(256, 256, 3, 3),
#       %convD_1.bias : Float(256),
#       %convD_2.weight : Float(128, 256, 3, 3),
#       %convD_2.bias : Float(128),
#       %convD_3.weight : Float(64, 128, 3, 3),
#       %convD_3.bias : Float(64),
#       %convD_4.weight : Float(32, 64, 3, 3),
#       %convD_4.bias : Float(32),
#       %convD_5.weight : Float(4, 32, 3, 3),
#       %convD_5.bias : Float(4),
#       %conv_before_transpose_1.weight : Float(256, 512, 3, 3),
#       %conv_before_transpose_1.bias : Float(256),
#       %transpose_1.weight : Float(256, 256, 3, 3),
#       %transpose_1.bias : Float(256),
#       %conv_after_transpose_1_1.weight : Float(256, 256, 3, 3),
#       %conv_after_transpose_1_1.bias : Float(256),
#       %transpose_2.weight : Float(256, 256, 3, 3),
#       %transpose_2.bias : Float(256),
#       %conv_after_transpose_2_1.weight : Float(128, 256, 3, 3),
#       %conv_after_transpose_2_1.bias : Float(128),
#       %transpose_3.weight : Float(256, 256, 3, 3),
#       %transpose_3.bias : Float(256),
#       %conv_after_transpose_3_1.weight : Float(128, 256, 3, 3),
#       %conv_after_transpose_3_1.bias : Float(128),
#       %transpose_4_1_a.weight : Float(256, 256, 3, 3),
#       %transpose_4_1_a.bias : Float(256),
#       %transpose_4_1_b.weight : Float(256, 256, 3, 3),
#       %transpose_4_1_b.bias : Float(256),
#       %conv_after_transpose_4_1.weight : Float(64, 256, 3, 3),
#       %conv_after_transpose_4_1.bias : Float(64),
#       %transpose_4_2.weight : Float(256, 256, 3, 3),
#       %transpose_4_2.bias : Float(256),
#       %conv_after_transpose_4_2.weight : Float(64, 256, 3, 3),
#       %conv_after_transpose_4_2.bias : Float(64),
#       %transpose_4_3.weight : Float(128, 128, 3, 3),
#       %transpose_4_3.bias : Float(128),
#       %conv_after_transpose_4_3.weight : Float(64, 128, 3, 3),
#       %conv_after_transpose_4_3.bias : Float(64),
#       %conv_middle_1.weight : Float(512, 256, 3, 3),
#       %conv_middle_1.bias : Float(512),
#       %conv_middle_2.weight : Float(512, 512, 3, 3),
#       %conv_middle_2.bias : Float(512),
#       %conv_middle_3.weight : Float(512, 512, 3, 3),
#       %conv_middle_3.bias : Float(512),
#       %conv_mid_4.weight : Float(256, 512, 3, 3),
#       %conv_mid_4.bias : Float(256),
#       %conv_lowest_1.weight : Float(256, 128, 3, 3),
#       %conv_lowest_1.bias : Float(256),
#       %conv_lowest_2.weight : Float(256, 256, 3, 3),
#       %conv_lowest_2.bias : Float(256),
#       %conv_lowest_3.weight : Float(256, 256, 3, 3),
#       %conv_lowest_3.bias : Float(256),
#       %conv_lowest_4.weight : Float(128, 256, 3, 3),
#       %conv_lowest_4.bias : Float(128),
#       %conv_scale1_1.weight : Float(128, 64, 3, 3),
#       %conv_scale1_1.bias : Float(128),
#       %conv_scale1_2.weight : Float(128, 128, 3, 3),
#       %conv_scale1_2.bias : Float(128),
#       %conv_scale1_3.weight : Float(64, 128, 3, 3),
#       %conv_scale1_3.bias : Float(64)):
#   %117 : Float(1, 3, 1, 1) = onnx::Constant[value=(1,1,.,.) =    104.0080  (1,2,.,.) =    116.6690  (1,3,.,.) =    122.6750 [ CPUFloatType{1,3,1,1} ]]()
#   %118 : Float(4, 3, 224, 224) = onnx::Sub(%0, %117)
#   %119 : Float(4, 64, 224, 224) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%118, %conv1_1.weight, %conv1_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %120 : Float(4, 64, 224, 224) = onnx::Relu(%119) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %121 : Float(4, 64, 224, 224) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%120, %conv1_2.weight, %conv1_2.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %122 : Float(4, 64, 224, 224) = onnx::Relu(%121) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %123 : Float(4, 64, 112, 112) = onnx::MaxPool[kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%122) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:539:0
#   %124 : Float(4, 128, 112, 112) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%123, %conv2_1.weight, %conv2_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %125 : Float(4, 128, 112, 112) = onnx::Relu(%124) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %126 : Float(4, 128, 112, 112) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%125, %conv2_2.weight, %conv2_2.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %127 : Float(4, 128, 112, 112) = onnx::Relu(%126) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %128 : Float(4, 128, 56, 56) = onnx::MaxPool[kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%127) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:539:0
#   %129 : Float(4, 256, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%128, %conv3_1.weight, %conv3_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %130 : Float(4, 256, 56, 56) = onnx::Relu(%129) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %131 : Float(4, 256, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%130, %conv3_2.weight, %conv3_2.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %132 : Float(4, 256, 56, 56) = onnx::Relu(%131) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %133 : Float(4, 256, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%132, %conv3_3.weight, %conv3_3.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %134 : Float(4, 256, 56, 56) = onnx::Relu(%133) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %135 : Float(4, 256, 28, 28) = onnx::MaxPool[kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%134) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:539:0
#   %136 : Float(4, 512, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%135, %conv4_1.weight, %conv4_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %137 : Float(4, 512, 28, 28) = onnx::Relu(%136) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %138 : Float(4, 512, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%137, %conv4_2.weight, %conv4_2.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %139 : Float(4, 512, 28, 28) = onnx::Relu(%138) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %140 : Float(4, 512, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%139, %conv4_3.weight, %conv4_3.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %141 : Float(4, 512, 28, 28) = onnx::Relu(%140) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %142 : Float(4, 512, 14, 14) = onnx::MaxPool[kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%141) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:539:0
#   %143 : Float(4, 512, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%142, %conv5_1.weight, %conv5_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %144 : Float(4, 512, 14, 14) = onnx::Relu(%143) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %145 : Float(4, 512, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%144, %conv5_2.weight, %conv5_2.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %146 : Float(4, 512, 14, 14) = onnx::Relu(%145) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %147 : Float(4, 512, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%146, %conv5_3.weight, %conv5_3.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %148 : Float(4, 512, 14, 14) = onnx::Relu(%147) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %149 : Float(4, 256, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%148, %conv_before_transpose_1.weight, %conv_before_transpose_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %150 : Float(4, 256, 14, 14) = onnx::Relu(%149) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %151 : Float(4, 256, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%150, %convA_1.weight, %convA_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %152 : Float(4, 256, 14, 14) = onnx::Relu(%151) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %153 : Float(4, 128, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%152, %convA_2.weight, %convA_2.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %154 : Float(4, 128, 14, 14) = onnx::Relu(%153) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %155 : Float(4, 64, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%154, %convA_3.weight, %convA_3.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %156 : Float(4, 64, 14, 14) = onnx::Relu(%155) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %157 : Float(4, 32, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%156, %convA_4.weight, %convA_4.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %158 : Float(4, 32, 14, 14) = onnx::Relu(%157) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %159 : Float(4, 4, 14, 14) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%158, %convA_5.weight, %convA_5.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %160 : Float(4, 512, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%135, %conv_middle_1.weight, %conv_middle_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %161 : Float(4, 512, 28, 28) = onnx::Relu(%160) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %162 : Float(4, 512, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%161, %conv_middle_2.weight, %conv_middle_2.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %163 : Float(4, 512, 28, 28) = onnx::Relu(%162) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %164 : Float(4, 512, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%163, %conv_middle_3.weight, %conv_middle_3.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %165 : Float(4, 512, 28, 28) = onnx::Relu(%164) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %166 : Float(4, 256, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%165, %conv_mid_4.weight, %conv_mid_4.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %167 : Float(4, 256, 28, 28) = onnx::Relu(%166) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %168 : Float(4, 256, 28, 28) = onnx::ConvTranspose[dilations=[1, 1], group=1, kernel_shape=[3, 3], output_padding=[1, 1], pads=[1, 1, 1, 1], strides=[2, 2]](%150, %transpose_1.weight, %transpose_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:790:0
#   %169 : Float(4, 256, 28, 28) = onnx::Relu(%168) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %170 : Float(4, 256, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%169, %conv_after_transpose_1_1.weight, %conv_after_transpose_1_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %171 : Float(4, 256, 28, 28) = onnx::Relu(%170) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %172 : Float(4, 512, 28, 28) = onnx::Concat[axis=1](%167, %171) # <ipython-input-24-748f84887bf1>:146:0
#   %173 : Float(4, 256, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%172, %convB_1.weight, %convB_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %174 : Float(4, 256, 28, 28) = onnx::Relu(%173) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %175 : Float(4, 128, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%174, %convB_2.weight, %convB_2.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %176 : Float(4, 128, 28, 28) = onnx::Relu(%175) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %177 : Float(4, 64, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%176, %convB_3.weight, %convB_3.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %178 : Float(4, 64, 28, 28) = onnx::Relu(%177) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %179 : Float(4, 32, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%178, %convB_4.weight, %convB_4.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %180 : Float(4, 32, 28, 28) = onnx::Relu(%179) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %181 : Float(4, 4, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%180, %convB_5.weight, %convB_5.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %182 : Float(4, 256, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%128, %conv_lowest_1.weight, %conv_lowest_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %183 : Float(4, 256, 56, 56) = onnx::Relu(%182) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %184 : Float(4, 256, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%183, %conv_lowest_2.weight, %conv_lowest_2.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %185 : Float(4, 256, 56, 56) = onnx::Relu(%184) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %186 : Float(4, 256, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%185, %conv_lowest_3.weight, %conv_lowest_3.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %187 : Float(4, 256, 56, 56) = onnx::Relu(%186) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %188 : Float(4, 128, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%187, %conv_lowest_4.weight, %conv_lowest_4.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %189 : Float(4, 128, 56, 56) = onnx::Relu(%188) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %190 : Float(4, 256, 56, 56) = onnx::ConvTranspose[dilations=[1, 1], group=1, kernel_shape=[3, 3], output_padding=[1, 1], pads=[1, 1, 1, 1], strides=[2, 2]](%167, %transpose_2.weight, %transpose_2.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:790:0
#   %191 : Float(4, 256, 56, 56) = onnx::Relu(%190) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %192 : Float(4, 128, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%191, %conv_after_transpose_2_1.weight, %conv_after_transpose_2_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %193 : Float(4, 128, 56, 56) = onnx::Relu(%192) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %194 : Float(4, 256, 56, 56) = onnx::ConvTranspose[dilations=[1, 1], group=1, kernel_shape=[3, 3], output_padding=[1, 1], pads=[0, 0, 0, 0], strides=[4, 4]](%150, %transpose_3.weight, %transpose_3.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:790:0
#   %195 : Float(4, 256, 56, 56) = onnx::Relu(%194) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %196 : Float(4, 128, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%195, %conv_after_transpose_3_1.weight, %conv_after_transpose_3_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %197 : Float(4, 128, 56, 56) = onnx::Relu(%196) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %198 : Float(4, 384, 56, 56) = onnx::Concat[axis=1](%189, %193, %197) # <ipython-input-24-748f84887bf1>:160:0
#   %199 : Float(4, 256, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%198, %convC_1.weight, %convC_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %200 : Float(4, 256, 56, 56) = onnx::Relu(%199) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %201 : Float(4, 128, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%200, %convC_2.weight, %convC_2.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %202 : Float(4, 128, 56, 56) = onnx::Relu(%201) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %203 : Float(4, 64, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%202, %convC_3.weight, %convC_3.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %204 : Float(4, 64, 56, 56) = onnx::Relu(%203) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %205 : Float(4, 32, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%204, %convC_4.weight, %convC_4.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %206 : Float(4, 32, 56, 56) = onnx::Relu(%205) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %207 : Float(4, 4, 56, 56) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%206, %convC_5.weight, %convC_5.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %208 : Float(4, 128, 112, 112) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%123, %conv_scale1_1.weight, %conv_scale1_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %209 : Float(4, 128, 112, 112) = onnx::Relu(%208) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %210 : Float(4, 128, 112, 112) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%209, %conv_scale1_2.weight, %conv_scale1_2.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %211 : Float(4, 128, 112, 112) = onnx::Relu(%210) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %212 : Float(4, 64, 112, 112) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%211, %conv_scale1_3.weight, %conv_scale1_3.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %213 : Float(4, 64, 112, 112) = onnx::Relu(%212) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %214 : Float(4, 256, 56, 56) = onnx::ConvTranspose[dilations=[1, 1], group=1, kernel_shape=[3, 3], output_padding=[1, 1], pads=[0, 0, 0, 0], strides=[4, 4]](%150, %transpose_4_1_a.weight, %transpose_4_1_a.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:790:0
#   %215 : Float(4, 256, 56, 56) = onnx::Relu(%214) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %216 : Float(4, 256, 112, 112) = onnx::ConvTranspose[dilations=[1, 1], group=1, kernel_shape=[3, 3], output_padding=[1, 1], pads=[1, 1, 1, 1], strides=[2, 2]](%215, %transpose_4_1_b.weight, %transpose_4_1_b.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:790:0
#   %217 : Float(4, 256, 112, 112) = onnx::Relu(%216) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %218 : Float(4, 64, 112, 112) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%217, %conv_after_transpose_4_1.weight, %conv_after_transpose_4_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %219 : Float(4, 64, 112, 112) = onnx::Relu(%218) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %220 : Float(4, 256, 112, 112) = onnx::ConvTranspose[dilations=[1, 1], group=1, kernel_shape=[3, 3], output_padding=[1, 1], pads=[0, 0, 0, 0], strides=[4, 4]](%167, %transpose_4_2.weight, %transpose_4_2.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:790:0
#   %221 : Float(4, 256, 112, 112) = onnx::Relu(%220) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %222 : Float(4, 64, 112, 112) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%221, %conv_after_transpose_4_2.weight, %conv_after_transpose_4_2.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %223 : Float(4, 64, 112, 112) = onnx::Relu(%222) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %224 : Float(4, 128, 112, 112) = onnx::ConvTranspose[dilations=[1, 1], group=1, kernel_shape=[3, 3], output_padding=[1, 1], pads=[1, 1, 1, 1], strides=[2, 2]](%189, %transpose_4_3.weight, %transpose_4_3.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:790:0
#   %225 : Float(4, 128, 112, 112) = onnx::Relu(%224) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %226 : Float(4, 64, 112, 112) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%225, %conv_after_transpose_4_3.weight, %conv_after_transpose_4_3.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %227 : Float(4, 64, 112, 112) = onnx::Relu(%226) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %228 : Float(4, 256, 112, 112) = onnx::Concat[axis=1](%213, %219, %223, %227) # <ipython-input-24-748f84887bf1>:183:0
#   %229 : Float(4, 256, 112, 112) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%228, %convD_1.weight, %convD_1.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %230 : Float(4, 256, 112, 112) = onnx::Relu(%229) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %231 : Float(4, 128, 112, 112) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%230, %convD_2.weight, %convD_2.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %232 : Float(4, 128, 112, 112) = onnx::Relu(%231) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %233 : Float(4, 64, 112, 112) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%232, %convD_3.weight, %convD_3.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %234 : Float(4, 64, 112, 112) = onnx::Relu(%233) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %235 : Float(4, 32, 112, 112) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%234, %convD_4.weight, %convD_4.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   %236 : Float(4, 32, 112, 112) = onnx::Relu(%235) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/functional.py:1061:0
#   %237 : Float(4, 4, 112, 112) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%236, %convD_5.weight, %convD_5.bias) # /Users/mahzadkhoshlessan/miniconda3/envs/ml/lib/python3.5/site-packages/torch/nn/modules/conv.py:346:0
#   return (%159, %181, %207, %237)
